# %% [markdown]
# # This notebook presents some approaches to cluster the dataset of the Netflix Challenge #
#
# This notebook is written in python. Eventually, the kernels have to be rewritten in julia.
# First we load the sparse Matrix containing the date, which was preprocessed by Thomas Camminady.

# %%
# unzip the files
from zipfile import ZipFile

# Create a ZipFile Object and load sample.zip in it
with ZipFile('NPY.zip', 'r') as zipObj:
   # Extract all the contents of zip file in current directory
   zipObj.extractall()

# %%
import numpy as np
# Load the sparse matrix

I = np.load('NPY/I.npy',allow_pickle=True) #Movie ID
J = np.load('NPY/J.npy',allow_pickle=True) #User ID
V = np.load('NPY/V.npy',allow_pickle=True) #Rating of user j for movie i.

# Show some stats
print("Non-zero entries of the rating matrix: ")
print(I.size)
print("Number of unique movies in the training set, i.e. columns of the matrix:")
print(np.unique(I).size)
print("Number of unique users in the training set, i.e. rows of the matrix:")
print(np.unique(J).size)
print("The highest user id is:")
print(np.amax(J))
# Out:
# Non-zero entries of the rating matrix:
# 100480507
# Number of unique movies in the training set, i.e. columns of the matrix:
# 17770
# Number of unique users in the training set, i.e. rows of the matrix:
# 480189
# The highest user id is:
# 2649429

# %%
# generate sparse arrays that are more suitable for our needs
user_count  = np.amax(J)+1
rating_count = I.size
# Generate an array with index = user_id.
user_ratings = np.empty((user_count,),dtype=object)

# Each user has a list of touples (movie_id, rating) representing his rated movies.
for idx in range(0,user_count):
    user_movies = list()
    user_ratings[idx] = user_movies

#assign to each user his list of rated films.
for rating_idx in range(0,rating_count):
    movie_tuple = (I[rating_idx],V[rating_idx])
    user_id= J[rating_idx]  
    user_ratings[user_id].append(movie_tuple)

# %%
# sort the rated movies of each user by id
for ratings in user_ratings: 
    ratings.sort(key=lambda tup: tup[0])

# %% [markdown]
# ## Analysing the problem ##
# The task at hand is to predict, how a given user rates a given movie. To fulfill this task, we have a (preprocessed) training dataset, that contains a sparse matrix S with entries S[i,j] = v, interpreted as movie i was ranked by user j with v stars. Additionally to v, we also store y, m, and d which represent the year, month, and day on which the rating was given.
#
# First, we try to solve the problem looking only at the ratings of the users and ignoring all other data, i.e. the date of the rating and the release date of the movie.
#
# ## Idea 1: Clustering ##
# One general Idea to solve this problem is to cluster the users, i.e. group users with shared interests. Once we can assign a user to the user group with which he has the most common interests, we can supplement the missing information about that user using the information from the group.
# The interest of the group can be modelled by creating the mean of the interests of its members. In our context, this means, that we assume, that the group rates a movie by the mean of all available ratings of its members. Then we simply assume, that the new user gives the film the same rating as the average of the group he was assigned to.
#
# Whereas it is rather simple to perform the second task of our idea, i.e. assign the mean rating to the new user, given that we know his group, it is not trivial to cluster the users in a meaningful manner.
#
# - The first question, we have to ask, is: What is the space, in which we cluster the users?
#     The first thing that comes into mind is that the clustering space is the space of movies, i.e. each movie represents one dimension of the clustering space.
#     In our context, this means that we have 17770 movies, i.e. 17770 dimensions of the clustering space.
#     We have 480189 users, i.e. 480189 data points in this clustering space, that need to be clustered.
#
# - The second quastion: How many user groups, i.e. clusters, do we need?
#     This question is hard to answer a priori. Furthermore, many clustering algorithms need this information before the execution.
#
#
#
# In the following, we present some clustering algorithms to perform this task.
#
# ### 1a) K-means clustering ###
#
# (Text copied from [here](https://en.wikipedia.org/wiki/K-means_clustering) )
#
# Training:
#
# Given an initial set of $k$ means $m_1,\dots,m_k$, the algorithm proceeds by alternating between two steps:
#
# *Assignment step*: Assign each observation to the cluster with the nearest mean: that with the least squared  Euclidean distance. (Mathematically, this means partitioning the observations according to the Voronoi diagram generated by the means.)
#  -  $S_i^{(t)} = \big \{ x_p : \big \| x_p - m^{(t)}_i \big \|^2 \le \big \| x_p - m^{(t)}_j \big \|^2 \ \forall j, 1 \le j \le k \big\}$,
#  -  where each $x_p$ is assigned to exactly one $S^{(t)}$, even if it could be assigned to two or more of them.
#
# *Update step*: Recalculate means (centroids) for observations assigned to each cluster.
#  - $m^{(t+1)}_i = \frac{1}{\left|S^{(t)}_i\right|} \sum_{x_j \in S^{(t)}_i} x_j $
#
# The algorithm has converged when the assignments no longer change. The algorithm does not guarantee to find the optimum.
#
# Classification:
# A given user is assigned to the group with smallest distance. Then the predicted rating of a movie is given by the mean of the ratings of the group.
#
# The algorithm is often presented as assigning objects to the nearest cluster by distance. Using a different distance function other than (squared) Euclidean distance may stop the algorithm from converging. Various modifications of $k$-means such as spherical $k$-means and K-medoids have been proposed to allow using other distance measures.
#
# #### Problems with K-means: ####
# Some problems arise when we naively try to apply $k$-means clustering
# - What is the location of a user (datapoint) in a movie (dimension), that he has not rated? How can we compute a distance, when not every user has rated every movie?
#
# - [Curse of dimensionality](https://en.wikipedia.org/wiki/Curse_of_dimensionality): In high dimensional datasets, a dataset almost always appears to be sparse. Therefore, the datapoints are very likely to have large distances between them and we have problems to assign them to a cluster.
#
#    In a mathematical context, this is paraphrased to the following: A $k$-means algorithm tries to minimize the variation of datapoints of a cluster by reassigning them. If the clustering space is too high dimensional, chances are high, that a given dataset has not enough statistical significance to be suited for such a procedure.

# %%
# k-means implementation

# Step 1: Create a better accessible sparse matrix pattern:
#         Each user is assigned to a list of touples (movie_id, rating), of movies that he has rated.

# %% [markdown]
# ### 1b) $k$- nearest neighbors clustering ###
#
# [$k$-nn](https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm) clustering is another method to classify a datapoints, i.e. predict the movie rating of a user.
# In contrast to the $k$- means clustering method, $k$-nn clustering does not assign the user to a group of similarily minded users. Therefore we do not have to think about a number of different user-groups before we start the algorithm.
#
# The idea is to look at the $k$ nearest neighbors of a given user. Depending on their ratings of the movie at hand, we determine the predicted rating for the given user and the movie at hand.
#
# There is no training phase for the $k$-nn algorithm in the sense of the $k$-means algorithm above.
#
# However, he problems with $k$-means persist in $k$-nn.

# %% [markdown]
# #### Solution Suggestions ####
#
# 1. Do not use Euklidean Distance, but instead a Similarity Coefficient, e.g. Pearson Correlation, computed from the correlation of the ratings of movies, which are rated by a pair of users.
#
# 2. Reduce Dimensionality by SVD or PCA
#
#
# ad 1) [Pearson Correlation Coefficient](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient) when applied to a sample is commonly represented by $r_{xy}$ and may be referred to as the ''sample correlation coefficient'' or the ''sample Pearson correlation coefficient''. We can obtain a formula for $r_{xy}$ by substituting estimates of the covariances and variances based on a statistical sample into the formula above. Given paired data $\left\{ (x_1,y_1),\ldots,(x_n,y_n) \right\}$ consisting of $n$ pairs, $r_{xy}$ is defined as:
#
# $
# r_{xy} =\frac{\sum\limits_{i \in I_{xy}}(r_{x,i}-\bar{r_x})(r_{y,i}-\bar{r_y})}{\sqrt{\sum\limits_{i \in I_{xy}}(r_{x,i}-\bar{r_x})^2}\sqrt{\sum\limits_{i \in I_{xy}}(r_{y,i}-\bar{r_y})^2}}
# $
#
# where:
#  - I is the index set of available samples. In our case, these are all movies that are rated by user x and y
#  - $n = \vert I\vert$ is sample size
#  - $r_{x,i}, r_{y,i}$ are the individual sample points indexed with $i$
#  - $\bar{r_x}=\frac{1}{n}\sum_{i=1}^n r_{x,i}$ (the sample mean); and analogously for $\bar{r_y}$
#
#
# In comparison, an Euklidean distance between two users is defined as
#
#  $
#  d_{x,y} = \sqrt{\sum\limits_{i=1}^N (r_{x,i}-{r_{y,i}})^2}
#  $
#
#  where $N$ is the number of movies, i.e. the dimensionality of the clustering space. Here we need to use each movie, i.e. dimension, even if it is not rated by the user.
#
#
# Remarks:
#     - Are user pairs with a low number of mutual ratings problematic? (I think not)

# %% [markdown]
# ## 1b) $k$-nn revisited ##
#
# Using the Pearson Corellation Coefficient, we get the following modified $k$-nn algorithm to predict the rating of user $x$ for movie $m$, $R_{x,m}$.
# Let $X$ be the set of users, $M$ be the set of movies.
#
# 0. Set the number of considered neighbors $k$, choose a movie id $m$ and a user-id $x$.
# 1. for $y\in X, y\not=x$:
#
#     a) compute $I_{x,y}=\{n\in M : n \text{ is rated by } x \text{ and } y \}$
#
#     b) compute $r_{xy}$ and store it.
#
# 2. Find the $y_1,\dots,y_k$ with the highest values of $r_{x,y}$.
# 3. $R_{x,m}= \frac{1}{k}\sum_{i=1}^k R_{y_i,m}$

# %%
# helper function intersection
def custom_intersection(list1, list2):
    idx_1 = 0;
    idx_2 = 0;
    res_list = list(); # list of triples [movie_id, rating_x, rating_y]
    while idx_1 < len(list1) and idx_2 < len(list2):
        if list1[idx_1][0] == list2[idx_2][0]:
            res_list.append( [list1[idx_1][1], list2[idx_2][1] ])
            idx_1 += 1 
            idx_2 += 1
        elif list1[idx_1][0] > list2[idx_2][0]:
            idx_2 += 1
        else:
            idx_1 += 1
            
    return res_list

# helper function getMovieRating (assumes, that user_ratings exist)
def getRating(id_user, id_movie):

    user = user_ratings[id_user];

    rating = -1 # token for non rated movies
    
    for key, value in user:
            if key == id_movie:
                rating = value;
    
    return rating #if user has not rated, return -1

# k_nn implementation, that outputs the k nearest neighbors of user_id
# assumes that the user_ratings sparse matrix is already in memory

def k_nn_memorized(user_id, k, users_mat, target_user, minimum_intersection = 5):
    
    '''
    user_id: user id of target_user
    user_mat: sparse matrix of all training users with their movies (array of list of tuples)
    target_user: user with id user_id
    minimum_intersectioN: target_user and its current neighbour candidate must have rated the same <minimum_intersection> movies.
    
    return: nearest neighbors: list of touples (user_id, pearson_corr with target user)
    '''
    
    pearson_ratings = list()
    for user_idx in range(0, users_mat.size-1):
        
        user_y = users_mat[user_idx]

        # get the cut set of rated movies of both users.
        intersec_movies = custom_intersection(target_user, user_y)

        # compute pearson correlation of these users
        if(len(intersec_movies)>10): # if the intersection is too small, we cant apply statistics to it
            ratings_x = np.array(intersec_movies)
            pear = np.corrcoef(ratings_x[:,0],ratings_x[:,1])
            pearson_ratings.append([user_idx, pear[0,1]])
            

    pearson_ratings.sort(key=lambda tup: tup[1], reverse = True)
    
    return (pearson_ratings[0:k-1])# (list of tuples (user, pearson_corr))

# %%
# Divide Data in training and test batch
train = user_ratings[0:2000000]
test =  user_ratings[2000001:2000300]
nn_per_user = list()

# %%
#load training savegame
import pickle
with open("nn_per_user.txt", "rb") as fp:   # Unpickling
    nn_per_user = pickle.load(fp)

# %%
print(len(nn_per_user))
# Out:
# 299

# %%
# perform training with k_nn
k = 10;
min_intersection = 10;

for idx in range (np.max(len(nn_per_user)-1, 0),test.size-1):
    user = test[idx]
    nn = k_nn_memorized(idx, k, train, user, min_intersection)
    nn_per_user.append(nn)
    
    b = "Trained on user " + str(idx) + " of " + str(test.size-1) + ". In percent: " + str(idx/(test.size-1) * 100)
    print (b, end="\r")

# %%
# safe the training:
import pickle
with open("nn_per_user.txt", "wb") as fp:   #Pickling
    pickle.dump(nn_per_user, fp)

# %%
# get results
realVsPred = list()
for idx in range (0,test.size): #test.size-1
    user = test[idx]
    for j_user in range (0,len(user)-1):
        idx_movie = user[j_user][0]
        nn = nn_per_user[idx]
        
        if(len(nn)!= 0):
            #print(nn)
            ratings = list();
            
            for idy in range(0,len(nn)):
                rating_y = getRating(nn[idy][0], idx_movie)
                
                if(rating_y != -1):
                    ratings.append(rating_y)

            if(len(ratings) != 0):
                prediction = np.mean(ratings)
                print("Test user: ", idx, " Movie ", idx_movie, " , prediction (", len(ratings), "neighbor ratings available): " , prediction, " real ", user[j_user][1])
                realVsPred.append((prediction, user[j_user][1]))
            #else: 
                #print("No feasible ratings for user ", idx , " and  movie ", idx_movie ,".")
# Out:
# Test user:  4  Movie  1307  , prediction ( 1 neighbor ratings available):  4.0  real  2
# Test user:  4  Movie  4432  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  4  Movie  7617  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  4  Movie  12232  , prediction ( 2 neighbor ratings available):  2.5  real  5
# Test user:  4  Movie  13050  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  4  Movie  14103  , prediction ( 2 neighbor ratings available):  4.5  real  5
# Test user:  4  Movie  15394  , prediction ( 2 neighbor ratings available):  3.5  real  5
# Test user:  66  Movie  30  , prediction ( 2 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  457  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  468  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  66  Movie  571  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  1220  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  1
# Test user:  66  Movie  1719  , prediction ( 1 neighbor ratings available):  2.0  real  4
# Test user:  66  Movie  1798  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  1865  , prediction ( 2 neighbor ratings available):  4.5  real  5
# Test user:  66  Movie  1905  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  66  Movie  1962  , prediction ( 2 neighbor ratings available):  3.0  real  3
# Test user:  66  Movie  2095  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  66  Movie  2122  , prediction ( 2 neighbor ratings available):  3.5  real  5
# Test user:  66  Movie  2152  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  1
# Test user:  66  Movie  2342  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  2372  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  2391  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  66  Movie  2465  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  2782  , prediction ( 3 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  2862  , prediction ( 1 neighbor ratings available):  1.0  real  5
# Test user:  66  Movie  3151  , prediction ( 2 neighbor ratings available):  4.5  real  3
# Test user:  66  Movie  3282  , prediction ( 4 neighbor ratings available):  1.75  real  4
# Test user:  66  Movie  3333  , prediction ( 1 neighbor ratings available):  5.0  real  1
# Test user:  66  Movie  3368  , prediction ( 1 neighbor ratings available):  5.0  real  2
# Test user:  66  Movie  3385  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  66  Movie  3798  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  3864  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  3917  , prediction ( 1 neighbor ratings available):  2.0  real  4
# Test user:  66  Movie  3925  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  66  Movie  3938  , prediction ( 2 neighbor ratings available):  3.5  real  3
# Test user:  66  Movie  4043  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  4
# Test user:  66  Movie  4123  , prediction ( 5 neighbor ratings available):  4.6  real  2
# Test user:  66  Movie  4227  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  4432  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  66  Movie  4590  , prediction ( 1 neighbor ratings available):  4.0  real  1
# Test user:  66  Movie  4640  , prediction ( 5 neighbor ratings available):  4.6  real  5
# Test user:  66  Movie  4829  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  66  Movie  4862  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  4951  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  4972  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  66  Movie  4996  , prediction ( 1 neighbor ratings available):  3.0  real  1
# Test user:  66  Movie  5054  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  5317  , prediction ( 3 neighbor ratings available):  4.0  real  1
# Test user:  66  Movie  5401  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  66  Movie  5472  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  66  Movie  5496  , prediction ( 2 neighbor ratings available):  4.5  real  2
# Test user:  66  Movie  5515  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  5522  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  66  Movie  5571  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  5704  , prediction ( 1 neighbor ratings available):  5.0  real  2
# Test user:  66  Movie  5732  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  5762  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  5862  , prediction ( 2 neighbor ratings available):  2.5  real  4
# Test user:  66  Movie  5926  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  5991  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  66  Movie  6029  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  6037  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  6099  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  6134  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  6196  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  66  Movie  6221  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  6366  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  6386  , prediction ( 1 neighbor ratings available):  4.0  real  2
# Test user:  66  Movie  6408  , prediction ( 2 neighbor ratings available):  4.5  real  4
# Test user:  66  Movie  6615  , prediction ( 1 neighbor ratings available):  4.0  real  2
# Test user:  66  Movie  6692  , prediction ( 2 neighbor ratings available):  4.0  real  2
# Test user:  66  Movie  6797  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  66  Movie  6971  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  6974  , prediction ( 2 neighbor ratings available):  4.5  real  4
# Test user:  66  Movie  7193  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  66  Movie  7240  , prediction ( 1 neighbor ratings available):  1.0  real  4
# Test user:  66  Movie  7331  , prediction ( 1 neighbor ratings available):  3.0  real  1
# Test user:  66  Movie  7590  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  7624  , prediction ( 3 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  7635  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  7745  , prediction ( 4 neighbor ratings available):  4.75  real  4
# Test user:  66  Movie  8107  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  66  Movie  8181  , prediction ( 1 neighbor ratings available):  5.0  real  2
# Test user:  66  Movie  8327  , prediction ( 2 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  8531  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  8764  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  8782  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  66  Movie  8832  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  8840  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  8904  , prediction ( 4 neighbor ratings available):  4.25  real  4
# Test user:  66  Movie  9205  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  66  Movie  9279  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  9728  , prediction ( 3 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  9756  , prediction ( 1 neighbor ratings available):  2.0  real  2
# Test user:  66  Movie  10168  , prediction ( 1 neighbor ratings available):  4.0  real  2
# Test user:  66  Movie  10225  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  10358  , prediction ( 2 neighbor ratings available):  4.0  real  2
# Test user:  66  Movie  10550  , prediction ( 1 neighbor ratings available):  4.0  real  2
# Test user:  66  Movie  10583  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  10730  , prediction ( 2 neighbor ratings available):  2.5  real  4
# Test user:  66  Movie  10774  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  66  Movie  10894  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  66  Movie  10928  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  11022  , prediction ( 2 neighbor ratings available):  4.0  real  2
# Test user:  66  Movie  11064  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  11242  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  11283  , prediction ( 6 neighbor ratings available):  4.833333333333333  real  2
# Test user:  66  Movie  11337  , prediction ( 3 neighbor ratings available):  3.3333333333333335  real  3
# Test user:  66  Movie  11521  , prediction ( 2 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  11677  , prediction ( 1 neighbor ratings available):  5.0  real  2
# Test user:  66  Movie  11812  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  11837  , prediction ( 1 neighbor ratings available):  2.0  real  2
# Test user:  66  Movie  11985  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  66  Movie  12172  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  66  Movie  12293  , prediction ( 2 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  12582  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  12690  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  12870  , prediction ( 3 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  13007  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  13081  , prediction ( 3 neighbor ratings available):  3.3333333333333335  real  2
# Test user:  66  Movie  13255  , prediction ( 2 neighbor ratings available):  4.5  real  3
# Test user:  66  Movie  13402  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  13412  , prediction ( 2 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  13439  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  66  Movie  13593  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  66  Movie  13728  , prediction ( 4 neighbor ratings available):  4.75  real  5
# Test user:  66  Movie  13763  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  13923  , prediction ( 2 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  14135  , prediction ( 1 neighbor ratings available):  4.0  real  2
# Test user:  66  Movie  14149  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  66  Movie  14192  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  66  Movie  14215  , prediction ( 1 neighbor ratings available):  5.0  real  2
# Test user:  66  Movie  14312  , prediction ( 2 neighbor ratings available):  4.5  real  4
# Test user:  66  Movie  14313  , prediction ( 6 neighbor ratings available):  4.833333333333333  real  1
# Test user:  66  Movie  14358  , prediction ( 2 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  14382  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  14454  , prediction ( 2 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  14545  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  14550  , prediction ( 6 neighbor ratings available):  4.833333333333333  real  5
# Test user:  66  Movie  14574  , prediction ( 1 neighbor ratings available):  4.0  real  1
# Test user:  66  Movie  14618  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  14691  , prediction ( 2 neighbor ratings available):  4.5  real  5
# Test user:  66  Movie  14890  , prediction ( 1 neighbor ratings available):  2.0  real  4
# Test user:  66  Movie  14928  , prediction ( 2 neighbor ratings available):  4.5  real  4
# Test user:  66  Movie  15107  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  66  Movie  15151  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  66  Movie  15345  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  66  Movie  15394  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  66  Movie  15755  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  15816  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  15853  , prediction ( 1 neighbor ratings available):  4.0  real  2
# Test user:  66  Movie  16150  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  16201  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  66  Movie  16272  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  66  Movie  16339  , prediction ( 1 neighbor ratings available):  2.0  real  2
# Test user:  66  Movie  16438  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  16668  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  66  Movie  16707  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  66  Movie  16792  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  66  Movie  16793  , prediction ( 1 neighbor ratings available):  2.0  real  4
# Test user:  66  Movie  16882  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  66  Movie  16954  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  66  Movie  17088  , prediction ( 2 neighbor ratings available):  3.5  real  3
# Test user:  66  Movie  17157  , prediction ( 6 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  17215  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  66  Movie  17281  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  66  Movie  17330  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  66  Movie  17339  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  66  Movie  17560  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  67  Movie  290  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  67  Movie  313  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  67  Movie  483  , prediction ( 3 neighbor ratings available):  2.6666666666666665  real  4
# Test user:  67  Movie  571  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  67  Movie  1145  , prediction ( 1 neighbor ratings available):  1.0  real  4
# Test user:  67  Movie  1307  , prediction ( 2 neighbor ratings available):  2.0  real  1
# Test user:  67  Movie  1810  , prediction ( 2 neighbor ratings available):  3.0  real  3
# Test user:  67  Movie  1865  , prediction ( 2 neighbor ratings available):  5.0  real  4
# Test user:  67  Movie  2200  , prediction ( 1 neighbor ratings available):  1.0  real  3
# Test user:  67  Movie  2495  , prediction ( 1 neighbor ratings available):  1.0  real  1
# Test user:  67  Movie  2889  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  67  Movie  3106  , prediction ( 1 neighbor ratings available):  2.0  real  4
# Test user:  67  Movie  3427  , prediction ( 2 neighbor ratings available):  2.0  real  3
# Test user:  67  Movie  3860  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  67  Movie  4123  , prediction ( 1 neighbor ratings available):  1.0  real  3
# Test user:  67  Movie  4315  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  67  Movie  4972  , prediction ( 1 neighbor ratings available):  1.0  real  3
# Test user:  67  Movie  4996  , prediction ( 3 neighbor ratings available):  2.0  real  4
# Test user:  67  Movie  5239  , prediction ( 1 neighbor ratings available):  1.0  real  2
# Test user:  67  Movie  5317  , prediction ( 8 neighbor ratings available):  1.375  real  4
# Test user:  67  Movie  5496  , prediction ( 1 neighbor ratings available):  4.0  real  2
# Test user:  67  Movie  5807  , prediction ( 1 neighbor ratings available):  1.0  real  2
# Test user:  67  Movie  5862  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  67  Movie  5926  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  67  Movie  6029  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  4
# Test user:  67  Movie  6099  , prediction ( 2 neighbor ratings available):  3.5  real  5
# Test user:  67  Movie  6134  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  67  Movie  6287  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  67  Movie  6347  , prediction ( 4 neighbor ratings available):  1.25  real  3
# Test user:  67  Movie  6350  , prediction ( 1 neighbor ratings available):  2.0  real  5
# Test user:  67  Movie  6386  , prediction ( 6 neighbor ratings available):  2.0  real  3
# Test user:  67  Movie  6450  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  67  Movie  6692  , prediction ( 1 neighbor ratings available):  2.0  real  2
# Test user:  67  Movie  6829  , prediction ( 1 neighbor ratings available):  1.0  real  3
# Test user:  67  Movie  6844  , prediction ( 1 neighbor ratings available):  1.0  real  3
# Test user:  67  Movie  6972  , prediction ( 3 neighbor ratings available):  3.0  real  4
# Test user:  67  Movie  7234  , prediction ( 7 neighbor ratings available):  1.5714285714285714  real  4
# Test user:  67  Movie  7249  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  67  Movie  7624  , prediction ( 4 neighbor ratings available):  3.5  real  4
# Test user:  67  Movie  8216  , prediction ( 1 neighbor ratings available):  4.0  real  2
# Test user:  67  Movie  8782  , prediction ( 5 neighbor ratings available):  4.6  real  3
# Test user:  67  Movie  9051  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  67  Movie  9340  , prediction ( 2 neighbor ratings available):  2.5  real  3
# Test user:  67  Movie  9617  , prediction ( 3 neighbor ratings available):  1.3333333333333333  real  4
# Test user:  67  Movie  9756  , prediction ( 5 neighbor ratings available):  1.2  real  4
# Test user:  67  Movie  10168  , prediction ( 1 neighbor ratings available):  2.0  real  2
# Test user:  67  Movie  10170  , prediction ( 2 neighbor ratings available):  1.0  real  3
# Test user:  67  Movie  10231  , prediction ( 2 neighbor ratings available):  5.0  real  4
# Test user:  67  Movie  10359  , prediction ( 1 neighbor ratings available):  1.0  real  4
# Test user:  67  Movie  10564  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  67  Movie  11064  , prediction ( 4 neighbor ratings available):  4.75  real  5
# Test user:  67  Movie  11149  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  67  Movie  11337  , prediction ( 1 neighbor ratings available):  2.0  real  4
# Test user:  67  Movie  11677  , prediction ( 2 neighbor ratings available):  2.0  real  4
# Test user:  67  Movie  11745  , prediction ( 1 neighbor ratings available):  3.0  real  1
# Test user:  67  Movie  12084  , prediction ( 2 neighbor ratings available):  4.5  real  4
# Test user:  67  Movie  12232  , prediction ( 3 neighbor ratings available):  5.0  real  4
# Test user:  67  Movie  12317  , prediction ( 2 neighbor ratings available):  2.5  real  4
# Test user:  67  Movie  12470  , prediction ( 3 neighbor ratings available):  3.0  real  4
# Test user:  67  Movie  12870  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  67  Movie  12911  , prediction ( 4 neighbor ratings available):  1.75  real  3
# Test user:  67  Movie  12918  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  67  Movie  13081  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  67  Movie  13102  , prediction ( 3 neighbor ratings available):  2.0  real  3
# Test user:  67  Movie  13462  , prediction ( 4 neighbor ratings available):  1.75  real  2
# Test user:  67  Movie  13748  , prediction ( 1 neighbor ratings available):  1.0  real  3
# Test user:  67  Movie  14313  , prediction ( 7 neighbor ratings available):  1.8571428571428572  real  2
# Test user:  67  Movie  14367  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  67  Movie  14538  , prediction ( 1 neighbor ratings available):  1.0  real  4
# Test user:  67  Movie  14550  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  67  Movie  14574  , prediction ( 2 neighbor ratings available):  1.0  real  4
# Test user:  67  Movie  14660  , prediction ( 3 neighbor ratings available):  1.6666666666666667  real  3
# Test user:  67  Movie  14712  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  67  Movie  15124  , prediction ( 3 neighbor ratings available):  2.3333333333333335  real  4
# Test user:  67  Movie  15156  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  67  Movie  15205  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  67  Movie  15393  , prediction ( 3 neighbor ratings available):  1.3333333333333333  real  4
# Test user:  67  Movie  15582  , prediction ( 1 neighbor ratings available):  1.0  real  2
# Test user:  67  Movie  15755  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  67  Movie  16242  , prediction ( 3 neighbor ratings available):  3.0  real  3
# Test user:  67  Movie  16339  , prediction ( 2 neighbor ratings available):  2.0  real  1
# Test user:  67  Movie  16740  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  67  Movie  16792  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  67  Movie  16879  , prediction ( 3 neighbor ratings available):  1.3333333333333333  real  4
# Test user:  67  Movie  17169  , prediction ( 2 neighbor ratings available):  3.5  real  3
# Test user:  67  Movie  17560  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  88  Movie  1798  , prediction ( 5 neighbor ratings available):  2.8  real  5
# Test user:  88  Movie  3610  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  88  Movie  4996  , prediction ( 1 neighbor ratings available):  3.0  real  1
# Test user:  88  Movie  5317  , prediction ( 6 neighbor ratings available):  3.1666666666666665  real  5
# Test user:  88  Movie  5582  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  5
# Test user:  88  Movie  5939  , prediction ( 2 neighbor ratings available):  2.0  real  5
# Test user:  88  Movie  6274  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  88  Movie  7219  , prediction ( 2 neighbor ratings available):  4.5  real  4
# Test user:  88  Movie  7234  , prediction ( 1 neighbor ratings available):  1.0  real  4
# Test user:  88  Movie  7624  , prediction ( 4 neighbor ratings available):  2.75  real  4
# Test user:  88  Movie  9340  , prediction ( 2 neighbor ratings available):  2.5  real  2
# Test user:  88  Movie  9614  , prediction ( 2 neighbor ratings available):  4.0  real  1
# Test user:  88  Movie  9628  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  88  Movie  9960  , prediction ( 4 neighbor ratings available):  3.75  real  4
# Test user:  88  Movie  10042  , prediction ( 4 neighbor ratings available):  4.75  real  5
# Test user:  88  Movie  11781  , prediction ( 3 neighbor ratings available):  4.0  real  5
# Test user:  88  Movie  12317  , prediction ( 2 neighbor ratings available):  2.5  real  4
# Test user:  88  Movie  12470  , prediction ( 3 neighbor ratings available):  2.6666666666666665  real  5
# Test user:  88  Movie  12582  , prediction ( 6 neighbor ratings available):  4.333333333333333  real  4
# Test user:  88  Movie  12918  , prediction ( 4 neighbor ratings available):  3.0  real  5
# Test user:  88  Movie  13651  , prediction ( 2 neighbor ratings available):  2.0  real  5
# Test user:  88  Movie  13748  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  88  Movie  14313  , prediction ( 2 neighbor ratings available):  2.5  real  4
# Test user:  88  Movie  14367  , prediction ( 3 neighbor ratings available):  2.6666666666666665  real  5
# Test user:  88  Movie  14590  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  88  Movie  15124  , prediction ( 5 neighbor ratings available):  3.2  real  5
# Test user:  88  Movie  16113  , prediction ( 2 neighbor ratings available):  2.0  real  4
# Test user:  88  Movie  16242  , prediction ( 2 neighbor ratings available):  2.5  real  2
# Test user:  88  Movie  16377  , prediction ( 5 neighbor ratings available):  3.6  real  5
# Test user:  88  Movie  16384  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  5
# Test user:  89  Movie  313  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  89  Movie  758  , prediction ( 2 neighbor ratings available):  3.5  real  4
# Test user:  89  Movie  1145  , prediction ( 3 neighbor ratings available):  3.0  real  5
# Test user:  89  Movie  1428  , prediction ( 3 neighbor ratings available):  3.3333333333333335  real  5
# Test user:  89  Movie  2152  , prediction ( 3 neighbor ratings available):  3.3333333333333335  real  4
# Test user:  89  Movie  2612  , prediction ( 2 neighbor ratings available):  3.0  real  5
# Test user:  89  Movie  3106  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  89  Movie  4306  , prediction ( 6 neighbor ratings available):  4.333333333333333  real  3
# Test user:  89  Movie  5317  , prediction ( 5 neighbor ratings available):  4.4  real  2
# Test user:  89  Movie  6287  , prediction ( 2 neighbor ratings available):  3.0  real  5
# Test user:  89  Movie  6386  , prediction ( 3 neighbor ratings available):  3.3333333333333335  real  2
# Test user:  89  Movie  6475  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  89  Movie  6692  , prediction ( 3 neighbor ratings available):  4.0  real  4
# Test user:  89  Movie  6844  , prediction ( 4 neighbor ratings available):  2.75  real  4
# Test user:  89  Movie  7234  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  89  Movie  7617  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  89  Movie  8181  , prediction ( 1 neighbor ratings available):  5.0  real  1
# Test user:  89  Movie  8393  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  89  Movie  8782  , prediction ( 4 neighbor ratings available):  2.25  real  4
# Test user:  89  Movie  9756  , prediction ( 5 neighbor ratings available):  2.8  real  5
# Test user:  89  Movie  10359  , prediction ( 3 neighbor ratings available):  2.6666666666666665  real  2
# Test user:  89  Movie  11149  , prediction ( 2 neighbor ratings available):  3.0  real  3
# Test user:  89  Movie  11314  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  89  Movie  12232  , prediction ( 4 neighbor ratings available):  3.5  real  4
# Test user:  89  Movie  12672  , prediction ( 2 neighbor ratings available):  2.5  real  5
# Test user:  89  Movie  12911  , prediction ( 2 neighbor ratings available):  3.5  real  5
# Test user:  89  Movie  12966  , prediction ( 2 neighbor ratings available):  3.5  real  4
# Test user:  89  Movie  13050  , prediction ( 4 neighbor ratings available):  4.5  real  2
# Test user:  89  Movie  13102  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  89  Movie  13462  , prediction ( 2 neighbor ratings available):  3.0  real  5
# Test user:  89  Movie  14149  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  89  Movie  14313  , prediction ( 6 neighbor ratings available):  3.5  real  4
# Test user:  89  Movie  14538  , prediction ( 7 neighbor ratings available):  3.2857142857142856  real  5
# Test user:  89  Movie  14890  , prediction ( 1 neighbor ratings available):  5.0  real  2
# Test user:  89  Movie  15472  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  89  Movie  15582  , prediction ( 7 neighbor ratings available):  3.2857142857142856  real  5
# Test user:  89  Movie  16377  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  89  Movie  16668  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  90  Movie  3864  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  90  Movie  5239  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  90  Movie  5730  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  123  Movie  457  , prediction ( 2 neighbor ratings available):  3.0  real  3
# Test user:  123  Movie  758  , prediction ( 2 neighbor ratings available):  3.0  real  3
# Test user:  123  Movie  886  , prediction ( 6 neighbor ratings available):  4.333333333333333  real  3
# Test user:  123  Movie  1073  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  123  Movie  1719  , prediction ( 3 neighbor ratings available):  2.3333333333333335  real  3
# Test user:  123  Movie  2329  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  123  Movie  2342  , prediction ( 4 neighbor ratings available):  3.75  real  4
# Test user:  123  Movie  2899  , prediction ( 2 neighbor ratings available):  3.5  real  4
# Test user:  123  Movie  2913  , prediction ( 6 neighbor ratings available):  3.3333333333333335  real  3
# Test user:  123  Movie  3282  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  4
# Test user:  123  Movie  3917  , prediction ( 5 neighbor ratings available):  3.4  real  4
# Test user:  123  Movie  3966  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  123  Movie  4733  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  123  Movie  4972  , prediction ( 5 neighbor ratings available):  3.6  real  3
# Test user:  123  Movie  4996  , prediction ( 5 neighbor ratings available):  3.0  real  3
# Test user:  123  Movie  5496  , prediction ( 6 neighbor ratings available):  3.5  real  3
# Test user:  123  Movie  5582  , prediction ( 6 neighbor ratings available):  4.5  real  5
# Test user:  123  Movie  6029  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  123  Movie  6134  , prediction ( 6 neighbor ratings available):  3.6666666666666665  real  1
# Test user:  123  Movie  6366  , prediction ( 1 neighbor ratings available):  2.0  real  5
# Test user:  123  Movie  7635  , prediction ( 4 neighbor ratings available):  2.75  real  3
# Test user:  123  Movie  7786  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  4
# Test user:  123  Movie  8782  , prediction ( 5 neighbor ratings available):  3.0  real  4
# Test user:  123  Movie  10114  , prediction ( 2 neighbor ratings available):  3.5  real  3
# Test user:  123  Movie  10358  , prediction ( 5 neighbor ratings available):  3.4  real  3
# Test user:  123  Movie  10947  , prediction ( 4 neighbor ratings available):  4.5  real  4
# Test user:  123  Movie  11022  , prediction ( 4 neighbor ratings available):  3.25  real  5
# Test user:  123  Movie  11077  , prediction ( 6 neighbor ratings available):  3.0  real  1
# Test user:  123  Movie  11812  , prediction ( 6 neighbor ratings available):  4.0  real  4
# Test user:  123  Movie  12155  , prediction ( 6 neighbor ratings available):  4.0  real  4
# Test user:  123  Movie  12161  , prediction ( 5 neighbor ratings available):  3.6  real  3
# Test user:  123  Movie  12582  , prediction ( 7 neighbor ratings available):  4.142857142857143  real  4
# Test user:  123  Movie  12690  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  123  Movie  12694  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  123  Movie  12732  , prediction ( 2 neighbor ratings available):  3.0  real  3
# Test user:  123  Movie  14215  , prediction ( 4 neighbor ratings available):  2.75  real  3
# Test user:  123  Movie  14274  , prediction ( 2 neighbor ratings available):  3.0  real  3
# Test user:  123  Movie  14890  , prediction ( 3 neighbor ratings available):  2.0  real  3
# Test user:  123  Movie  15646  , prediction ( 3 neighbor ratings available):  3.0  real  2
# Test user:  123  Movie  15955  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  123  Movie  16150  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  123  Movie  16784  , prediction ( 2 neighbor ratings available):  3.5  real  3
# Test user:  123  Movie  17355  , prediction ( 6 neighbor ratings available):  3.6666666666666665  real  4
# Test user:  124  Movie  30  , prediction ( 6 neighbor ratings available):  4.5  real  5
# Test user:  124  Movie  299  , prediction ( 2 neighbor ratings available):  4.0  real  3
# Test user:  124  Movie  313  , prediction ( 2 neighbor ratings available):  2.5  real  4
# Test user:  124  Movie  361  , prediction ( 2 neighbor ratings available):  3.0  real  3
# Test user:  124  Movie  457  , prediction ( 2 neighbor ratings available):  3.5  real  4
# Test user:  124  Movie  571  , prediction ( 4 neighbor ratings available):  4.5  real  2
# Test user:  124  Movie  705  , prediction ( 1 neighbor ratings available):  2.0  real  4
# Test user:  124  Movie  758  , prediction ( 3 neighbor ratings available):  3.3333333333333335  real  3
# Test user:  124  Movie  886  , prediction ( 2 neighbor ratings available):  3.5  real  4
# Test user:  124  Movie  1073  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  1110  , prediction ( 1 neighbor ratings available):  2.0  real  5
# Test user:  124  Movie  1144  , prediction ( 2 neighbor ratings available):  5.0  real  4
# Test user:  124  Movie  1145  , prediction ( 2 neighbor ratings available):  2.5  real  3
# Test user:  124  Movie  1180  , prediction ( 2 neighbor ratings available):  3.5  real  4
# Test user:  124  Movie  1220  , prediction ( 5 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  1307  , prediction ( 3 neighbor ratings available):  3.3333333333333335  real  3
# Test user:  124  Movie  1406  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  1470  , prediction ( 4 neighbor ratings available):  4.5  real  3
# Test user:  124  Movie  1542  , prediction ( 3 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  1650  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  124  Movie  1744  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  124  Movie  1754  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  1798  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  5
# Test user:  124  Movie  1810  , prediction ( 2 neighbor ratings available):  4.5  real  4
# Test user:  124  Movie  1865  , prediction ( 2 neighbor ratings available):  2.5  real  3
# Test user:  124  Movie  1905  , prediction ( 5 neighbor ratings available):  4.8  real  4
# Test user:  124  Movie  1962  , prediction ( 4 neighbor ratings available):  3.75  real  4
# Test user:  124  Movie  2095  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  124  Movie  2152  , prediction ( 2 neighbor ratings available):  4.0  real  3
# Test user:  124  Movie  2200  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  124  Movie  2209  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  124  Movie  2254  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  124  Movie  2372  , prediction ( 4 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  2391  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  124  Movie  2452  , prediction ( 5 neighbor ratings available):  5.0  real  3
# Test user:  124  Movie  2580  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  124  Movie  2660  , prediction ( 2 neighbor ratings available):  4.5  real  5
# Test user:  124  Movie  2755  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  2782  , prediction ( 2 neighbor ratings available):  4.5  real  5
# Test user:  124  Movie  2800  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  124  Movie  2848  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  2862  , prediction ( 2 neighbor ratings available):  5.0  real  5
# Test user:  124  Movie  2874  , prediction ( 2 neighbor ratings available):  2.5  real  2
# Test user:  124  Movie  2913  , prediction ( 5 neighbor ratings available):  3.0  real  4
# Test user:  124  Movie  3106  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  3
# Test user:  124  Movie  3282  , prediction ( 4 neighbor ratings available):  4.5  real  4
# Test user:  124  Movie  3290  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  124  Movie  3312  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  124  Movie  3371  , prediction ( 3 neighbor ratings available):  4.666666666666667  real  2
# Test user:  124  Movie  3427  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  3513  , prediction ( 2 neighbor ratings available):  3.5  real  5
# Test user:  124  Movie  3521  , prediction ( 2 neighbor ratings available):  4.0  real  3
# Test user:  124  Movie  3610  , prediction ( 2 neighbor ratings available):  5.0  real  5
# Test user:  124  Movie  3624  , prediction ( 3 neighbor ratings available):  5.0  real  4
# Test user:  124  Movie  3730  , prediction ( 4 neighbor ratings available):  4.25  real  4
# Test user:  124  Movie  3756  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  3
# Test user:  124  Movie  3860  , prediction ( 6 neighbor ratings available):  3.5  real  3
# Test user:  124  Movie  3875  , prediction ( 3 neighbor ratings available):  4.666666666666667  real  3
# Test user:  124  Movie  3938  , prediction ( 4 neighbor ratings available):  4.75  real  4
# Test user:  124  Movie  3966  , prediction ( 2 neighbor ratings available):  3.0  real  3
# Test user:  124  Movie  4123  , prediction ( 1 neighbor ratings available):  1.0  real  4
# Test user:  124  Movie  4302  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  5
# Test user:  124  Movie  4306  , prediction ( 2 neighbor ratings available):  4.5  real  5
# Test user:  124  Movie  4315  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  124  Movie  4356  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  124  Movie  4364  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  124  Movie  4432  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  3
# Test user:  124  Movie  4472  , prediction ( 4 neighbor ratings available):  4.5  real  4
# Test user:  124  Movie  4545  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  4590  , prediction ( 1 neighbor ratings available):  1.0  real  3
# Test user:  124  Movie  4640  , prediction ( 3 neighbor ratings available):  3.3333333333333335  real  5
# Test user:  124  Movie  4656  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  4
# Test user:  124  Movie  4745  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  124  Movie  4874  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  124  Movie  4931  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  124  Movie  4972  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  124  Movie  4996  , prediction ( 2 neighbor ratings available):  2.5  real  3
# Test user:  124  Movie  5056  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  124  Movie  5071  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  124  Movie  5085  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  4
# Test user:  124  Movie  5181  , prediction ( 4 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  5293  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  124  Movie  5317  , prediction ( 5 neighbor ratings available):  3.4  real  3
# Test user:  124  Movie  5401  , prediction ( 3 neighbor ratings available):  4.0  real  3
# Test user:  124  Movie  5496  , prediction ( 5 neighbor ratings available):  3.6  real  3
# Test user:  124  Movie  5708  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  124  Movie  5787  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  5807  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  5836  , prediction ( 2 neighbor ratings available):  4.0  real  3
# Test user:  124  Movie  6030  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  124  Movie  6037  , prediction ( 4 neighbor ratings available):  3.5  real  4
# Test user:  124  Movie  6042  , prediction ( 2 neighbor ratings available):  4.5  real  3
# Test user:  124  Movie  6099  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  124  Movie  6134  , prediction ( 3 neighbor ratings available):  2.3333333333333335  real  4
# Test user:  124  Movie  6166  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  6206  , prediction ( 5 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  6287  , prediction ( 5 neighbor ratings available):  3.8  real  4
# Test user:  124  Movie  6386  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  6408  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  124  Movie  6428  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  124  Movie  6475  , prediction ( 2 neighbor ratings available):  2.5  real  4
# Test user:  124  Movie  6497  , prediction ( 2 neighbor ratings available):  4.5  real  3
# Test user:  124  Movie  6692  , prediction ( 2 neighbor ratings available):  2.5  real  4
# Test user:  124  Movie  6739  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  6797  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  5
# Test user:  124  Movie  6829  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  4
# Test user:  124  Movie  6859  , prediction ( 4 neighbor ratings available):  3.5  real  3
# Test user:  124  Movie  6874  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  6902  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  6971  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  5
# Test user:  124  Movie  6972  , prediction ( 2 neighbor ratings available):  3.0  real  4
# Test user:  124  Movie  6974  , prediction ( 5 neighbor ratings available):  4.2  real  4
# Test user:  124  Movie  7057  , prediction ( 2 neighbor ratings available):  5.0  real  2
# Test user:  124  Movie  7219  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  7281  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  124  Movie  7303  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  124  Movie  7330  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  124  Movie  7364  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  124  Movie  7416  , prediction ( 2 neighbor ratings available):  5.0  real  5
# Test user:  124  Movie  7509  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  124  Movie  7617  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  7624  , prediction ( 2 neighbor ratings available):  3.5  real  5
# Test user:  124  Movie  7635  , prediction ( 3 neighbor ratings available):  3.3333333333333335  real  2
# Test user:  124  Movie  7745  , prediction ( 1 neighbor ratings available):  5.0  real  5
# Test user:  124  Movie  7767  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  3
# Test user:  124  Movie  7904  , prediction ( 1 neighbor ratings available):  1.0  real  1
# Test user:  124  Movie  7928  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  8327  , prediction ( 3 neighbor ratings available):  5.0  real  5
# Test user:  124  Movie  8387  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  124  Movie  8393  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  8413  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  124  Movie  8524  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  124  Movie  8644  , prediction ( 2 neighbor ratings available):  3.5  real  4
# Test user:  124  Movie  8717  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  124  Movie  8806  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  8883  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  8904  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  4
# Test user:  124  Movie  9054  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  9188  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  124  Movie  9340  , prediction ( 2 neighbor ratings available):  3.5  real  4
# Test user:  124  Movie  9426  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  9469  , prediction ( 1 neighbor ratings available):  4.0  real  1
# Test user:  124  Movie  9481  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  9592  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  9617  , prediction ( 2 neighbor ratings available):  3.5  real  5
# Test user:  124  Movie  9628  , prediction ( 2 neighbor ratings available):  5.0  real  4
# Test user:  124  Movie  9645  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  124  Movie  9728  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  9818  , prediction ( 3 neighbor ratings available):  4.0  real  3
# Test user:  124  Movie  9828  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  9960  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  124  Movie  10042  , prediction ( 3 neighbor ratings available):  4.666666666666667  real  5
# Test user:  124  Movie  10123  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  124  Movie  10168  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  2
# Test user:  124  Movie  10358  , prediction ( 2 neighbor ratings available):  3.5  real  4
# ...
# Test user:  230  Movie  8387  , prediction ( 4 neighbor ratings available):  3.75  real  2
# Test user:  230  Movie  8447  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  230  Movie  8644  , prediction ( 4 neighbor ratings available):  4.25  real  4
# Test user:  230  Movie  8651  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  8782  , prediction ( 3 neighbor ratings available):  2.0  real  3
# Test user:  230  Movie  8784  , prediction ( 2 neighbor ratings available):  4.5  real  3
# Test user:  230  Movie  8840  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  8904  , prediction ( 5 neighbor ratings available):  4.6  real  4
# Test user:  230  Movie  9037  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  230  Movie  9051  , prediction ( 2 neighbor ratings available):  4.5  real  2
# Test user:  230  Movie  9170  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  9205  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  230  Movie  9378  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  9528  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  9685  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  230  Movie  9728  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  230  Movie  9818  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  230  Movie  9828  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  9960  , prediction ( 6 neighbor ratings available):  3.8333333333333335  real  3
# Test user:  230  Movie  10042  , prediction ( 9 neighbor ratings available):  4.888888888888889  real  4
# Test user:  230  Movie  10053  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  10105  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  230  Movie  10117  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  230  Movie  10225  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  10230  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  10255  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  10491  , prediction ( 1 neighbor ratings available):  2.0  real  4
# Test user:  230  Movie  10583  , prediction ( 4 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  10820  , prediction ( 7 neighbor ratings available):  4.285714285714286  real  4
# Test user:  230  Movie  10928  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  10947  , prediction ( 3 neighbor ratings available):  5.0  real  4
# Test user:  230  Movie  11182  , prediction ( 4 neighbor ratings available):  3.75  real  4
# Test user:  230  Movie  11198  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  11209  , prediction ( 2 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  11214  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  11265  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  11279  , prediction ( 2 neighbor ratings available):  4.5  real  3
# Test user:  230  Movie  11283  , prediction ( 7 neighbor ratings available):  4.857142857142857  real  4
# Test user:  230  Movie  11323  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  11398  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  230  Movie  11490  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  11521  , prediction ( 9 neighbor ratings available):  5.0  real  4
# Test user:  230  Movie  11573  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  11701  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  230  Movie  11837  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  11926  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  11994  , prediction ( 2 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  12074  , prediction ( 3 neighbor ratings available):  5.0  real  4
# Test user:  230  Movie  12090  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  12232  , prediction ( 3 neighbor ratings available):  2.6666666666666665  real  3
# Test user:  230  Movie  12343  , prediction ( 2 neighbor ratings available):  4.5  real  2
# Test user:  230  Movie  12473  , prediction ( 2 neighbor ratings available):  4.5  real  3
# Test user:  230  Movie  12600  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  12778  , prediction ( 2 neighbor ratings available):  2.5  real  3
# Test user:  230  Movie  12881  , prediction ( 2 neighbor ratings available):  2.5  real  4
# Test user:  230  Movie  12918  , prediction ( 4 neighbor ratings available):  3.5  real  4
# Test user:  230  Movie  13050  , prediction ( 2 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  13052  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  230  Movie  13129  , prediction ( 1 neighbor ratings available):  3.0  real  2
# Test user:  230  Movie  13195  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  13302  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  230  Movie  13391  , prediction ( 2 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  13580  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  13651  , prediction ( 2 neighbor ratings available):  4.0  real  4
# Test user:  230  Movie  13728  , prediction ( 6 neighbor ratings available):  4.5  real  5
# Test user:  230  Movie  13748  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  13763  , prediction ( 3 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  13887  , prediction ( 2 neighbor ratings available):  3.5  real  3
# Test user:  230  Movie  13923  , prediction ( 3 neighbor ratings available):  4.0  real  4
# Test user:  230  Movie  14050  , prediction ( 5 neighbor ratings available):  4.8  real  3
# Test user:  230  Movie  14109  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  14185  , prediction ( 2 neighbor ratings available):  4.5  real  4
# Test user:  230  Movie  14240  , prediction ( 9 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  14280  , prediction ( 2 neighbor ratings available):  3.0  real  4
# Test user:  230  Movie  14296  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  14312  , prediction ( 2 neighbor ratings available):  3.0  real  4
# Test user:  230  Movie  14358  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  3
# Test user:  230  Movie  14484  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  14527  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  2
# Test user:  230  Movie  14621  , prediction ( 7 neighbor ratings available):  4.571428571428571  real  3
# Test user:  230  Movie  14667  , prediction ( 3 neighbor ratings available):  4.333333333333333  real  4
# Test user:  230  Movie  14670  , prediction ( 1 neighbor ratings available):  2.0  real  3
# Test user:  230  Movie  14691  , prediction ( 6 neighbor ratings available):  3.3333333333333335  real  4
# Test user:  230  Movie  14780  , prediction ( 4 neighbor ratings available):  3.5  real  3
# Test user:  230  Movie  14918  , prediction ( 1 neighbor ratings available):  2.0  real  4
# Test user:  230  Movie  14928  , prediction ( 2 neighbor ratings available):  3.5  real  3
# Test user:  230  Movie  14961  , prediction ( 8 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  15048  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  15062  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  230  Movie  15107  , prediction ( 5 neighbor ratings available):  4.0  real  4
# Test user:  230  Movie  15124  , prediction ( 7 neighbor ratings available):  2.7142857142857144  real  4
# Test user:  230  Movie  15156  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  15339  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  15381  , prediction ( 2 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  15394  , prediction ( 2 neighbor ratings available):  5.0  real  2
# Test user:  230  Movie  15421  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  15436  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  15582  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  2
# Test user:  230  Movie  15755  , prediction ( 2 neighbor ratings available):  4.5  real  4
# Test user:  230  Movie  15758  , prediction ( 3 neighbor ratings available):  3.6666666666666665  real  4
# Test user:  230  Movie  15818  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  15922  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  16008  , prediction ( 2 neighbor ratings available):  4.5  real  4
# Test user:  230  Movie  16113  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  16128  , prediction ( 2 neighbor ratings available):  4.5  real  3
# Test user:  230  Movie  16150  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  16272  , prediction ( 4 neighbor ratings available):  4.0  real  2
# Test user:  230  Movie  16384  , prediction ( 6 neighbor ratings available):  3.8333333333333335  real  4
# Test user:  230  Movie  16452  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  16604  , prediction ( 1 neighbor ratings available):  5.0  real  2
# Test user:  230  Movie  16668  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  230  Movie  16825  , prediction ( 1 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  16948  , prediction ( 1 neighbor ratings available):  4.0  real  2
# Test user:  230  Movie  16954  , prediction ( 8 neighbor ratings available):  4.5  real  4
# Test user:  230  Movie  17085  , prediction ( 1 neighbor ratings available):  5.0  real  4
# Test user:  230  Movie  17088  , prediction ( 3 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  17169  , prediction ( 3 neighbor ratings available):  3.0  real  3
# Test user:  230  Movie  17308  , prediction ( 1 neighbor ratings available):  4.0  real  3
# Test user:  230  Movie  17324  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  230  Movie  17355  , prediction ( 6 neighbor ratings available):  3.1666666666666665  real  3
# Test user:  230  Movie  17474  , prediction ( 2 neighbor ratings available):  4.0  real  5
# Test user:  230  Movie  17482  , prediction ( 1 neighbor ratings available):  4.0  real  4
# Test user:  230  Movie  17560  , prediction ( 6 neighbor ratings available):  4.333333333333333  real  3
# Test user:  230  Movie  17762  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  243  Movie  528  , prediction ( 2 neighbor ratings available):  2.5  real  5
# Test user:  243  Movie  2372  , prediction ( 4 neighbor ratings available):  4.5  real  5
# Test user:  243  Movie  3638  , prediction ( 2 neighbor ratings available):  4.5  real  4
# Test user:  243  Movie  5513  , prediction ( 1 neighbor ratings available):  5.0  real  3
# Test user:  243  Movie  6134  , prediction ( 5 neighbor ratings available):  4.6  real  5
# Test user:  243  Movie  12732  , prediction ( 5 neighbor ratings available):  4.2  real  4
# Test user:  243  Movie  13074  , prediction ( 1 neighbor ratings available):  4.0  real  5
# Test user:  243  Movie  15205  , prediction ( 5 neighbor ratings available):  3.8  real  5
# Test user:  284  Movie  1798  , prediction ( 7 neighbor ratings available):  4.0  real  3
# Test user:  284  Movie  4972  , prediction ( 5 neighbor ratings available):  3.6  real  1
# Test user:  284  Movie  4996  , prediction ( 3 neighbor ratings available):  4.0  real  2
# Test user:  284  Movie  5317  , prediction ( 7 neighbor ratings available):  2.7142857142857144  real  2
# Test user:  284  Movie  5496  , prediction ( 6 neighbor ratings available):  3.5  real  2
# Test user:  284  Movie  5727  , prediction ( 1 neighbor ratings available):  3.0  real  5
# Test user:  284  Movie  6274  , prediction ( 6 neighbor ratings available):  3.3333333333333335  real  5
# Test user:  284  Movie  6386  , prediction ( 6 neighbor ratings available):  3.3333333333333335  real  1
# Test user:  284  Movie  6844  , prediction ( 2 neighbor ratings available):  3.0  real  1
# Test user:  284  Movie  6972  , prediction ( 4 neighbor ratings available):  3.25  real  4
# Test user:  284  Movie  7234  , prediction ( 5 neighbor ratings available):  3.6  real  3
# Test user:  284  Movie  9340  , prediction ( 6 neighbor ratings available):  2.8333333333333335  real  2
# Test user:  284  Movie  9617  , prediction ( 3 neighbor ratings available):  3.3333333333333335  real  3
# Test user:  284  Movie  9756  , prediction ( 5 neighbor ratings available):  3.2  real  2
# Test user:  284  Movie  10123  , prediction ( 3 neighbor ratings available):  3.0  real  2
# Test user:  284  Movie  10168  , prediction ( 4 neighbor ratings available):  2.75  real  2
# Test user:  284  Movie  11677  , prediction ( 6 neighbor ratings available):  3.1666666666666665  real  2
# Test user:  284  Movie  11781  , prediction ( 7 neighbor ratings available):  3.4285714285714284  real  3
# Test user:  284  Movie  11859  , prediction ( 2 neighbor ratings available):  3.0  real  2
# Test user:  284  Movie  11888  , prediction ( 1 neighbor ratings available):  3.0  real  4
# Test user:  284  Movie  12317  , prediction ( 5 neighbor ratings available):  3.4  real  4
# Test user:  284  Movie  12435  , prediction ( 5 neighbor ratings available):  3.8  real  3
# Test user:  284  Movie  12470  , prediction ( 4 neighbor ratings available):  3.0  real  3
# Test user:  284  Movie  12675  , prediction ( 3 neighbor ratings available):  3.3333333333333335  real  4
# Test user:  284  Movie  12918  , prediction ( 6 neighbor ratings available):  2.5  real  3
# Test user:  284  Movie  13081  , prediction ( 6 neighbor ratings available):  3.0  real  2
# Test user:  284  Movie  13651  , prediction ( 6 neighbor ratings available):  3.1666666666666665  real  3
# Test user:  284  Movie  14313  , prediction ( 4 neighbor ratings available):  4.0  real  2
# Test user:  284  Movie  14367  , prediction ( 6 neighbor ratings available):  3.1666666666666665  real  3
# Test user:  284  Movie  14712  , prediction ( 5 neighbor ratings available):  2.6  real  3
# Test user:  284  Movie  14928  , prediction ( 7 neighbor ratings available):  3.2857142857142856  real  4
# Test user:  284  Movie  15124  , prediction ( 5 neighbor ratings available):  2.8  real  5
# Test user:  284  Movie  15205  , prediction ( 7 neighbor ratings available):  3.0  real  3
# Test user:  284  Movie  16242  , prediction ( 4 neighbor ratings available):  2.75  real  2
# Test user:  284  Movie  16377  , prediction ( 8 neighbor ratings available):  3.875  real  3
# Test user:  284  Movie  16384  , prediction ( 7 neighbor ratings available):  3.7142857142857144  real  5
# Test user:  284  Movie  16954  , prediction ( 7 neighbor ratings available):  4.0  real  5
# Test user:  284  Movie  17154  , prediction ( 8 neighbor ratings available):  3.75  real  4
# Test user:  284  Movie  17302  , prediction ( 2 neighbor ratings available):  2.5  real  4

# %%
# evaluate results
RMSE = 0
for pair in realVsPred:
    RMSE += (pair[0]-pair[1])*(pair[0]-pair[1])
RMSE = np.sqrt(RMSE)
RMSE /= len(realVsPred)
print("RMSE of the k_nn predictions is :", RMSE)
# Out:
# RMSE of the k_nn predictions is : 0.035873915497458296

# %% [markdown]
# ## Discussion ##
# Not bad, given that we have very few neighbors that have watched the same movie!
# But there some things to note:
# * We have only calculated the RMSE, if we have neighbors available, that have actually rated that move. (Huge Bias in the results!)
# * Quite often,  we have only a few neighbors that have watched the same move.
#
# Both problems are partially caused by the same underlying problem.
# We have calculated the $k$ nearest neighbors for a given user $x$. This does not factor in, that the $k$ nearest neighbors must have watched the movie.
#
# We can overcome this problem in two ways.
# 1. We can compute live for a given movie and a given user the $k$ nearest neighbors and use their rating (computationally quite expensive, since we have to perform the training above for each movie).
# 2. We store not only the $k$ neighbors with the best pearson coefficient, but all users with descending pearson coefficient. This is quite memory expensive, given the amount of users available.
#
# We additionally go for a weaker version of approach 2 by storing not only the $k$ nearest, but the $N*k$ nearest neighbors, where $N$ is a scaling factor.
